# %%
import networkx as nx
import sqlite3
import pandas as pd

conn = sqlite3.connect('/Users/Admin/Documents/Projects/Kairos/main/data/GTFS.db')

# %%
MG = nx.MultiDiGraph() # initialise Graph

# %%
## Add Nodes

# %%
stops = pd.read_sql_query('SELECT * FROM gtfs_stops', conn)
stops.head(1)
# Out:
#   stop_id stop_name stop_desc  stop_lat   stop_lon zone_id stop_url stop_code  \
# 0   18848  Clínicas      None -23.55419 -46.670723    None     None      None
#
#   stop_street stop_city stop_region stop_postcode stop_country location_type  \
# 0        None      None        None          None         None          None
#
#   parent_station stop_timezone
# 0           None          None

# %%
for i, row in stops.iterrows():
    MG.add_node(row['stop_id'], location={'lat': row['stop_lat'], 'long': row['stop_lon']})

# %% [markdown]
# ## Add Edges

# %%
def unicode_to_seconds(a):
    a = map(int, a.split(':'))
    return a[0] * 3600 + a[1] * 60 + a[2]

# %%
stops_time = pd.read_sql_query('SELECT * FROM gtfs_stop_times', conn)
stops_time.head(1)
# Out:
#      trip_id arrival_time departure_time stop_id  stop_sequence stop_headsign  \
# 0  1012-10-0     03:40:00       03:40:00  301708              1          None
#
#   pickup_type drop_off_type shape_dist_traveled timepoint  \
# 0        None          None                None      None
#
#    arrival_time_seconds  departure_time_seconds
# 0                 13200                   13200

# %%
for i, row in stops_time.iterrows():
    
    try:
        partida, chegada = stops_time.iloc[i], stops_time.iloc[i + 1]
    except:
        break
    if chegada['trip_id'] == partida['trip_id']:
        MG.add_edge(partida['stop_id'], chegada['stop_id'], 
                    attr = {'tempo': chegada['departure_time_seconds']-partida['arrival_time_seconds'],
                      'trip_id': chegada['trip_id']}
        )

# %% [markdown]
# ## Add frequency

# %%
frequencies = pd.read_sql_query('SELECT * FROM gtfs_frequencies', conn)

# %%
frequencies.head(70)
# Out:
#       trip_id start_time  end_time  headway_secs  start_time_seconds  \
# 0   1012-10-0   03:00:00  03:59:00          1800               10800
# 1   1012-10-0   04:00:00  04:59:00           420               14400
# 2   1012-10-0   05:00:00  05:59:00           420               18000
# 3   1012-10-0   06:00:00  06:59:00           480               21600
# 4   1012-10-0   07:00:00  07:59:00           420               25200
# 5   1012-10-0   08:00:00  08:59:00           480               28800
# 6   1012-10-0   09:00:00  09:59:00           420               32400
# 7   1012-10-0   10:00:00  10:59:00           480               36000
# 8   1012-10-0   11:00:00  11:59:00           420               39600
# 9   1012-10-0   12:00:00  12:59:00           480               43200
# 10  1012-10-0   13:00:00  13:59:00           420               46800
# 11  1012-10-0   14:00:00  14:59:00           480               50400
# 12  1012-10-0   15:00:00  15:59:00           420               54000
# 13  1012-10-0   16:00:00  16:59:00           360               57600
# 14  1012-10-0   17:00:00  17:59:00           360               61200
# 15  1012-10-0   18:00:00  18:59:00           360               64800
# 16  1012-10-0   19:00:00  19:59:00           420               68400
# 17  1012-10-0   20:00:00  20:59:00           600               72000
# 18  1012-10-0   21:00:00  21:59:00           600               75600
# 19  1012-10-0   22:00:00  22:59:00           600               79200
# 20  1012-10-0   23:00:00  23:59:00          3600               82800
# 21  1012-10-1   00:00:00  00:59:00           900                   0
# 22  1012-10-1   04:00:00  04:59:00           600               14400
# 23  1012-10-1   05:00:00  05:59:00           420               18000
# 24  1012-10-1   06:00:00  06:59:00           420               21600
# 25  1012-10-1   07:00:00  07:59:00           480               25200
# 26  1012-10-1   08:00:00  08:59:00           420               28800
# 27  1012-10-1   09:00:00  09:59:00           480               32400
# 28  1012-10-1   10:00:00  10:59:00           420               36000
# 29  1012-10-1   11:00:00  11:59:00           480               39600
# ..        ...        ...       ...           ...                 ...
# 40  1012-10-1   22:00:00  22:59:00           600               79200
# 41  1012-10-1   23:00:00  23:59:00           720               82800
# 42  1015-10-0   04:00:00  04:59:00          3600               14400
# 43  1015-10-0   05:00:00  05:59:00          1200               18000
# 44  1015-10-0   06:00:00  06:59:00          1200               21600
# 45  1015-10-0   07:00:00  07:59:00          1800               25200
# 46  1015-10-0   08:00:00  08:59:00          1800               28800
# 47  1015-10-0   09:00:00  09:59:00          3600               32400
# 48  1015-10-0   10:00:00  10:59:00          1800               36000
# 49  1015-10-0   11:00:00  11:59:00          3600               39600
# 50  1015-10-0   12:00:00  12:59:00          1800               43200
# 51  1015-10-0   13:00:00  13:59:00          3600               46800
# 52  1015-10-0   14:00:00  14:59:00          1800               50400
# 53  1015-10-0   15:00:00  15:59:00          3600               54000
# 54  1015-10-0   16:00:00  16:59:00          1200               57600
# 55  1015-10-0   17:00:00  17:59:00          1200               61200
# 56  1015-10-0   18:00:00  18:59:00          1800               64800
# 57  1015-10-0   19:00:00  19:59:00          1200               68400
# 58  1015-10-0   20:00:00  20:59:00          3600               72000
# 59  1015-10-0   21:00:00  21:59:00          3600               75600
# 60  1015-10-0   22:00:00  22:59:00          1800               79200
# 61  1016-10-0   00:00:00  00:59:00          1800                   0
# 62  1016-10-0   04:00:00  04:59:00          1800               14400
# 63  1016-10-0   05:00:00  05:59:00           360               18000
# 64  1016-10-0   06:00:00  06:59:00           240               21600
# 65  1016-10-0   07:00:00  07:59:00           240               25200
# 66  1016-10-0   08:00:00  08:59:00           300               28800
# 67  1016-10-0   09:00:00  09:59:00           300               32400
# 68  1016-10-0   10:00:00  10:59:00           360               36000
# 69  1016-10-0   11:00:00  11:59:00           360               39600
#
#     end_time_seconds
# 0              14340
# 1              17940
# 2              21540
# 3              25140
# 4              28740
# 5              32340
# 6              35940
# 7              39540
# 8              43140
# 9              46740
# 10             50340
# 11             53940
# 12             57540
# 13             61140
# 14             64740
# 15             68340
# 16             71940
# 17             75540
# 18             79140
# 19             82740
# 20             86340
# 21              3540
# 22             17940
# 23             21540
# 24             25140
# 25             28740
# 26             32340
# 27             35940
# 28             39540
# 29             43140
# ..               ...
# 40             82740
# 41             86340
# 42             17940
# 43             21540
# 44             25140
# 45             28740
# 46             32340
# 47             35940
# 48             39540
# 49             43140
# 50             46740
# 51             50340
# 52             53940
# 53             57540
# 54             61140
# 55             64740
# 56             68340
# 57             71940
# 58             75540
# 59             79140
# 60             82740
# 61              3540
# 62             17940
# 63             21540
# 64             25140
# 65             28740
# 15          None        None          None                None      None
#
#     arrival_time_seconds  departure_time_seconds
# 0                  13200                   13200
# 15                  3000                    3000

# %%
for i, row in stops_time_first.iterrows():
    
    print i, row['trip_id']
    
    lista = []
    lista.append(row['arrival_time_seconds'])
    trip = frequencies[frequencies['trip_id'] == row['trip_id']]
    
    # Para baixo
    while 1:
        
        ultimo = lista[-1] 
        timetable = trip[(trip["start_time_seconds"] <= ultimo) & (trip["end_time_seconds"] + 60 >= ultimo)]
        
        if len(timetable) > 0:
            
            soma = timetable['headway_secs'].values[0] + ultimo
            
            if soma <= 86340:
                lista.append(timetable['headway_secs'].values[0] + ultimo)
            else: 
                lista.append(soma - 86340)
            
        else:
            break
    # Para cima        
    while 1:
        
        primeiro = lista[0]
        timetable_atual = trip[(trip["start_time_seconds"] <= primeiro) & (trip["end_time_seconds"] + 60 >= primeiro)]
        timetable_anterior = trip[(trip['end_time_seconds']) == timetable_atual['start_time_seconds'].values[0] - 60]
        
        # com timetable anterior
        if len(timetable_anterior) > 0:
            
            subt = primeiro - timetable_anterior['headway_secs'].values[0]
            
            # se dentro da timetable anterior
            if subt <= timetable_anterior['end_time_seconds']:
                lista.insert(0, subt)
            
            else:
                lista.insert(0, primeiro - timetable_atual['headway_secs'].values[0])
            
        # se dentro da timetable atual mas timetable anterior inexistente 
        elif (primeiro - timetable_anterior['headway_secs'].values[0]) < 0
        
        elif (primeiro - timetable_atual['headway_secs'].values[0]) >= timetable_atual['start_time_seconds'].values[0]:
            
            lista.insert(0, primeiro - timetable_atual['headway_secs'].values[0])
        
        else:
            break
            
    print lista
# Out:
# 0 1012-10-0
# [11400, 13200, 15000, 15420, 15840, 16260, 16680, 17100, 17520, 17940, 18360, 18780, 19200, 19620, 20040, 20460, 20880, 21300, 21720, 22200, 22680, 23160, 23640, 24120, 24600, 25080, 25560, 25980, 26400, 26820, 27240, 27660, 28080, 28500, 28920, 29400, 29880, 30360, 30840, 31320, 31800, 32280, 32760, 33180, 33600, 34020, 34440, 34860, 35280, 35700, 36120, 36600, 37080, 37560, 38040, 38520, 39000, 39480, 39960, 40380, 40800, 41220, 41640, 42060, 42480, 42900, 43320, 43800, 44280, 44760, 45240, 45720, 46200, 46680, 47160, 47580, 48000, 48420, 48840, 49260, 49680, 50100, 50520, 51000, 51480, 51960, 52440, 52920, 53400, 53880, 54360, 54780, 55200, 55620, 56040, 56460, 56880, 57300, 57720, 58080, 58440, 58800, 59160, 59520, 59880, 60240, 60600, 60960, 61320, 61680, 62040, 62400, 62760, 63120, 63480, 63840, 64200, 64560, 64920, 65280, 65640, 66000, 66360, 66720, 67080, 67440, 67800, 68160, 68520, 68940, 69360, 69780, 70200, 70620, 71040, 71460, 71880, 72300, 72900, 73500, 74100, 74700, 75300, 75900, 76500, 77100, 77700, 78300, 78900, 79500, 80100, 80700, 81300, 81900, 82500, 83100, 360]
# 15 1012-10-1
# [300, 1200, 2100, 3000, 3900]
# 36 1015-10-0
# [14400, 18000, 21600, 22800, 24000, 25200, 26400, 28200, 30000, 31800, 33600, 37200, 39000, 40800, 44400, 46200, 48000, 51600, 53400, 55200, 58800, 60000, 61200, 62400, 63600, 64800, 66000, 67800, 69600, 70800, 72000, 73200, 76800, 80400, 82200, 84000]
# 40 1016-10-0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-1755343a83f3> in <module>()
#      37
#      38             # se dentro da timetable anterior
# ---> 39             if subt <= timetable_anterior['end_time_seconds']:
#      40                 lista.insert(0, subt)
#      41
#
# /Users/Admin/anaconda/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other, axis)
#     739             return NotImplemented
#     740         elif isinstance(other, (np.ndarray, pd.Index)):
# --> 741             if len(self) != len(other):
#     742                 raise ValueError('Lengths must match to compare')
#     743             return self._constructor(na_op(self.values, np.asarray(other)),
#
# TypeError: len() of unsized object

# %%
for i, row in stops_time_first.iterrows():
    print (i)
    
    volta = 1
    lista=[]
    lista.append(row['arrival_time_seconds'])
    while 1:
        
        ultimo = lista[-1]

        trip = frequencies[frequencies['trip_id'] == row['trip_id']]
        trip = trip[(trip["start_time_seconds"] <= ultimo) & (trip["end_time_seconds"] >= ultimo)]
        
        
        while (ultimo < 86340 and len(trip)==0):
            ultimo = ultimo + 60
            trip = frequencies[frequencies['trip_id'] == row['trip_id']]
            trip = trip[(trip["start_time_seconds"] <= ultimo) & (trip["end_time_seconds"] >= ultimo)]
            
        if i==36:
            print (lista)
        
        soma = ultimo + trip['headway_secs'].values[0]
            
        if (volta>1 and soma>lista[0]):
            break
            
        if soma < 86340:
            lista.append(soma)
        
        elif soma > 86340:
            volta = volta+1
            #print soma
            
            ultimo = soma - 86340
            
            trip = frequencies[frequencies['trip_id'] == row['trip_id']]
            trip = trip[(trip["start_time_seconds"] <= ultimo) & (trip["end_time_seconds"] >= ultimo)]
            print (len(trip))
            if len(trip) > 0:
                #print ('oi')
                #print (trip['headway_secs'].values)
                lista.append(ultimo + trip['headway_secs'].values[0])
            else:
                break
        else:
            break
    print (lista)
    
    #if 'viagens' in MG.node['301729']:
    #    MG.node['301729']['viagens'][row['trip_id']] = lista
    #else:
    #    MG.node['301729']['viagens'] = {row['trip_id']: lista}
# Out:
# 0
# 0
# [13200, 15000, 15420, 15840, 16260, 16680, 17100, 17520, 17940, 18360, 18780, 19200, 19620, 20040, 20460, 20880, 21300, 21720, 22200, 22680, 23160, 23640, 24120, 24600, 25080, 25560, 25980, 26400, 26820, 27240, 27660, 28080, 28500, 28920, 29400, 29880, 30360, 30840, 31320, 31800, 32280, 32760, 33180, 33600, 34020, 34440, 34860, 35280, 35700, 36120, 36600, 37080, 37560, 38040, 38520, 39000, 39480, 39960, 40380, 40800, 41220, 41640, 42060, 42480, 42900, 43320, 43800, 44280, 44760, 45240, 45720, 46200, 46680, 47160, 47580, 48000, 48420, 48840, 49260, 49680, 50100, 50520, 51000, 51480, 51960, 52440, 52920, 53400, 53880, 54360, 54780, 55200, 55620, 56040, 56460, 56880, 57300, 57720, 58080, 58440, 58800, 59160, 59520, 59880, 60240, 60600, 60960, 61320, 61680, 62040, 62400, 62760, 63120, 63480, 63840, 64200, 64560, 64920, 65280, 65640, 66000, 66360, 66720, 67080, 67440, 67800, 68160, 68520, 68940, 69360, 69780, 70200, 70620, 71040, 71460, 71880, 72300, 72900, 73500, 74100, 74700, 75300, 75900, 76500, 77100, 77700, 78300, 78900, 79500, 80100, 80700, 81300, 81900, 82500, 83100]
# 15
# 1
# [3000, 3900, 15000, 15600, 16200, 16800, 17400, 18000, 18420, 18840, 19260, 19680, 20100, 20520, 20940, 21360, 21780, 22200, 22620, 23040, 23460, 23880, 24300, 24720, 25140, 25560, 26040, 26520, 27000, 27480, 27960, 28440, 28920, 29340, 29760, 30180, 30600, 31020, 31440, 31860, 32280, 32700, 33180, 33660, 34140, 34620, 35100, 35580, 36060, 36480, 36900, 37320, 37740, 38160, 38580, 39000, 39420, 39840, 40320, 40800, 41280, 41760, 42240, 42720, 43200, 43620, 44040, 44460, 44880, 45300, 45720, 46140, 46560, 46980, 47460, 47940, 48420, 48900, 49380, 49860, 50340, 50820, 51240, 51660, 52080, 52500, 52920, 53340, 53760, 54180, 54660, 55140, 55620, 56100, 56580, 57060, 57540, 58020, 58440, 58860, 59280, 59700, 60120, 60540, 60960, 61380, 61740, 62100, 62460, 62820, 63180, 63540, 63900, 64260, 64620, 64980, 65340, 65700, 66060, 66420, 66780, 67140, 67500, 67860, 68220, 68580, 68940, 69300, 69660, 70020, 70380, 70740, 71100, 71460, 71820, 72180, 72660, 73140, 73620, 74100, 74580, 75060, 75540, 76020, 76620, 77220, 77820, 78420, 79020, 79620, 80220, 80820, 81420, 82020, 82620, 83220, 83940, 84660, 85380, 86100, 1380, 2280]
# 36
# [18000]
# [18000, 19200]
# [18000, 19200, 20400]
# [18000, 19200, 20400, 21600]
# [18000, 19200, 20400, 21600, 22800]
# [18000, 19200, 20400, 21600, 22800, 24000]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200, 45000]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200, 45000, 46800]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200, 45000, 46800, 50400]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200, 45000, 46800, 50400, 52200]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200, 45000, 46800, 50400, 52200, 54000]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200, 45000, 46800, 50400, 52200, 54000, 57600]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200, 45000, 46800, 50400, 52200, 54000, 57600, 58800]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200, 45000, 46800, 50400, 52200, 54000, 57600, 58800, 60000]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200, 45000, 46800, 50400, 52200, 54000, 57600, 58800, 60000, 61200]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200, 45000, 46800, 50400, 52200, 54000, 57600, 58800, 60000, 61200, 62400]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200, 45000, 46800, 50400, 52200, 54000, 57600, 58800, 60000, 61200, 62400, 63600]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200, 45000, 46800, 50400, 52200, 54000, 57600, 58800, 60000, 61200, 62400, 63600, 64800]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200, 45000, 46800, 50400, 52200, 54000, 57600, 58800, 60000, 61200, 62400, 63600, 64800, 66600]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200, 45000, 46800, 50400, 52200, 54000, 57600, 58800, 60000, 61200, 62400, 63600, 64800, 66600, 68400]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200, 45000, 46800, 50400, 52200, 54000, 57600, 58800, 60000, 61200, 62400, 63600, 64800, 66600, 68400, 69600]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200, 45000, 46800, 50400, 52200, 54000, 57600, 58800, 60000, 61200, 62400, 63600, 64800, 66600, 68400, 69600, 70800]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200, 45000, 46800, 50400, 52200, 54000, 57600, 58800, 60000, 61200, 62400, 63600, 64800, 66600, 68400, 69600, 70800, 72000]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200, 45000, 46800, 50400, 52200, 54000, 57600, 58800, 60000, 61200, 62400, 63600, 64800, 66600, 68400, 69600, 70800, 72000, 75600]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200, 45000, 46800, 50400, 52200, 54000, 57600, 58800, 60000, 61200, 62400, 63600, 64800, 66600, 68400, 69600, 70800, 72000, 75600, 79200]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200, 45000, 46800, 50400, 52200, 54000, 57600, 58800, 60000, 61200, 62400, 63600, 64800, 66600, 68400, 69600, 70800, 72000, 75600, 79200, 81000]
# [18000, 19200, 20400, 21600, 22800, 24000, 25200, 27000, 28800, 30600, 32400, 36000, 37800, 39600, 43200, 45000, 46800, 50400, 52200, 54000, 57600, 58800, 60000, 61200, 62400, 63600, 64800, 66600, 68400, 69600, 70800, 72000, 75600, 79200, 81000, 82800]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-dfe73b3d38cc> in <module>()
#      21             print (lista)
#      22
# ---> 23         soma = ultimo + trip['headway_secs'].values[0]
#      24
#      25         if (volta>1 and soma>lista[0]):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
lista.append(row['arrival_time_seconds'])
while 1:
    ultimo = lista[-1]
    trip = frequencies[frequencies['trip_id'] == row['trip_id']]
    trip = trip[(trip["start_time_seconds"] < ultimo) & (trip["end_time_seconds"] > ultimo)]
    lista.append(ultimo + trip['headway_secs'])

# %%
trip = frequencies[frequencies['trip_id'] == '1012-10-0']
trip[(trip["start_time_seconds"] < ultimo) & (trip["end_time_seconds"] > ultimo)]
