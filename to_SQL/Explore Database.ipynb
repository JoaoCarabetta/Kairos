# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
conn = sqlite3.connect('/Users/Admin/Documents/Projects/Kairos/main/data/GTFS.db')

# %%
df = pd.read_sql_query('SELECT * FROM gtfs_stops', conn)
df.dtypes
# Out:
# stop_id            object
# stop_name          object
# stop_desc          object
# stop_lat          float64
# stop_lon          float64
# zone_id            object
# stop_url           object
# stop_code          object
# stop_street        object
# stop_city          object
# stop_region        object
# stop_postcode      object
# stop_country       object
# location_type      object
# parent_station     object
# stop_timezone      object
# dtype: object

# %%
type(df.loc[2, 'stop_id'])
# Out:
# unicode

# %%
plt.scatter(df['stop_lon'], df['stop_lat'], marker='o')
